# %% [markdown]
# # Introduction
# In this notebook we will be trying some merging methods for pandas dataframes like Merge , Join and Concat.

# %%
import pandas as pd 
import numpy as np

# %%
df1=pd.read_csv("D:/CareerStudy/AnalyticsLearningVideos/MergingDataframes_in_Pandas/LOTR.csv")

# %%
df1.head()
# Out:
#    FellowshipID FirstName     Skills
# 0        1001.0     Frodo     Hiding
# 1        1002.0   Samwise  Gardening
# 2        1003.0   Gandalf     Spells
# 3        1004.0    Pippin  Fireworks
# 4           NaN       NaN        NaN

# %%
df2=pd.read_csv("D:/CareerStudy/AnalyticsLearningVideos/MergingDataframes_in_Pandas/LOTR2.csv")

# %%
df2.head()
# Out:
#    FellowshipID FirstName   Age  Unnamed: 3
# 0          1001     Frodo    50         NaN
# 1          1002   Samwise    39         NaN
# 2          1006   Legolas  2931         NaN
# 3          1007    Elrond  6520         NaN
# 4          1008  Barromir    51         NaN

# %%
df2.drop(["Unnamed: 3"], axis=1,inplace=True) # Dropping unnecessary column

# %%
df2.head()
# Out:
#    FellowshipID FirstName   Age
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
df1.dropna(axis=0,inplace=True) # Dropping unnecessary rows.

# %%
df1.head()
# Out:
#    FellowshipID FirstName     Skills
# 0        1001.0     Frodo     Hiding
# 1        1002.0   Samwise  Gardening
# 2        1003.0   Gandalf     Spells
# 3        1004.0    Pippin  Fireworks

# %% [markdown]
# So we have ready df1 and df2 for use in this notebook.

# %% [markdown]
# ## 1. Merge Function
#
# Merge function is the most important function when we talk of joining dataframes like SQL joins .

# %%
df1.merge(df2)
# Out:
#    FellowshipID FirstName     Skills  Age
# 0        1001.0     Frodo     Hiding   50
# 1        1002.0   Samwise  Gardening   39

# %% [markdown]
# In merge function the default join is inner join of the two columns and it considers only those columns present in both
# dataframe and takes a inner join of two.

# %%
df1.merge(df2 , how="inner" , on=["FellowshipID"])
# Out:
#    FellowshipID FirstName_x     Skills FirstName_y  Age
# 0        1001.0       Frodo     Hiding       Frodo   50
# 1        1002.0     Samwise  Gardening     Samwise   39

# %% [markdown]
# When we take "on" argument then it gives all the columns name with default suffixes of _x and _y
# and inner is similar to SQLs inner function.

# %%
df1.merge(df2 , how="inner" , on=["FellowshipID","FirstName"])
# Out:
#    FellowshipID FirstName     Skills  Age
# 0        1001.0     Frodo     Hiding   50
# 1        1002.0   Samwise  Gardening   39

# %% [markdown]
# Now when we made two columns as base of join so it is going to take them only once.

# %%
df1.merge(df2 , how="left" , on=["FellowshipID","FirstName"]) # similar to SQL left join.
# Out:
#    FellowshipID FirstName     Skills   Age
# 0        1001.0     Frodo     Hiding  50.0
# 1        1002.0   Samwise  Gardening  39.0
# 2        1003.0   Gandalf     Spells   NaN
# 3        1004.0    Pippin  Fireworks   NaN

# %%
df1.merge(df2 , how="right" , on=["FellowshipID","FirstName"]) # similar to SQL right join.
# Out:
#    FellowshipID FirstName     Skills   Age
# 0        1001.0     Frodo     Hiding    50
# 1        1002.0   Samwise  Gardening    39
# 2        1006.0   Legolas        NaN  2931
# 3        1007.0    Elrond        NaN  6520
# 4        1008.0  Barromir        NaN    51

# %%
df1.merge(df2 , how="outer" , on=["FellowshipID","FirstName"]) # similar to SQL outer join.
# Out:
#    FellowshipID FirstName     Skills     Age
# 0        1001.0     Frodo     Hiding    50.0
# 1        1002.0   Samwise  Gardening    39.0
# 2        1003.0   Gandalf     Spells     NaN
# 3        1004.0    Pippin  Fireworks     NaN
# 4        1006.0   Legolas        NaN  2931.0
# 5        1007.0    Elrond        NaN  6520.0
# 6        1008.0  Barromir        NaN    51.0

# %%
df1.merge(df2 , how="cross" )   # similar to SQL cross join.
# Out:
#     FellowshipID_x FirstName_x     Skills  FellowshipID_y FirstName_y   Age
# 0           1001.0       Frodo     Hiding            1001       Frodo    50
# 1           1001.0       Frodo     Hiding            1002     Samwise    39
# 2           1001.0       Frodo     Hiding            1006     Legolas  2931
# 3           1001.0       Frodo     Hiding            1007      Elrond  6520
# 4           1001.0       Frodo     Hiding            1008    Barromir    51
# 5           1002.0     Samwise  Gardening            1001       Frodo    50
# 6           1002.0     Samwise  Gardening            1002     Samwise    39
# 7           1002.0     Samwise  Gardening            1006     Legolas  2931
# 8           1002.0     Samwise  Gardening            1007      Elrond  6520
# 9           1002.0     Samwise  Gardening            1008    Barromir    51
# 10          1003.0     Gandalf     Spells            1001       Frodo    50
# 11          1003.0     Gandalf     Spells            1002     Samwise    39
# 12          1003.0     Gandalf     Spells            1006     Legolas  2931
# 13          1003.0     Gandalf     Spells            1007      Elrond  6520
# 14          1003.0     Gandalf     Spells            1008    Barromir    51
# 15          1004.0      Pippin  Fireworks            1001       Frodo    50
# 16          1004.0      Pippin  Fireworks            1002     Samwise    39
# 17          1004.0      Pippin  Fireworks            1006     Legolas  2931
# 18          1004.0      Pippin  Fireworks            1007      Elrond  6520
# 19          1004.0      Pippin  Fireworks            1008    Barromir    51

# %% [markdown]
# ## 2. Join Function

# %%
df1.join(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df1.join(df2)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9263, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort)
#    9109 def join(
#    9110     self,
#    9111     other: DataFrame | Series,
#    (...)
#    9116     sort: bool = False,
#    9117 ) -> DataFrame:
#    9118     """
#    9119     Join columns of another DataFrame.
#    9120
#    (...)
#    9261     5  K1  A5   B1
#    9262     """
# -> 9263     return self._join_compat(
#    9264         other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9265     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9294, in DataFrame._join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9285     if how == "cross":
#    9286         return merge(
#    9287             self,
#    9288             other,
#    (...)
#    9292             sort=sort,
#    9293         )
# -> 9294     return merge(
#    9295         self,
#    9296         other,
#    9297         left_on=on,
#    9298         how=how,
#    9299         left_index=on is None,
#    9300         right_index=True,
#    9301         suffixes=(lsuffix, rsuffix),
#    9302         sort=sort,
#    9303     )
#    9304 else:
#    9305     if on is not None:
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:122, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
#     107     op = _MergeOperation(
#     108         left,
#     109         right,
#    (...)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:718, in _MergeOperation.get_result(self)
#     714     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     716 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 718 llabels, rlabels = _items_overlap_with_suffix(
#     719     self.left._info_axis, self.right._info_axis, self.suffixes
#     720 )
#     722 lindexers = {1: left_indexer} if left_indexer is not None else {}
#     723 rindexers = {1: right_indexer} if right_indexer is not None else {}
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:2317, in _items_overlap_with_suffix(left, right, suffixes)
#    2314 lsuffix, rsuffix = suffixes
#    2316 if not lsuffix and not rsuffix:
# -> 2317     raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2319 def renamer(x, suffix):
#    2320     """
#    2321     Rename the left and right indices.
#    2322
#    (...)
#    2333     x : renamed column name
#    2334     """
#
# ValueError: columns overlap but no suffix specified: Index(['FellowshipID', 'FirstName'], dtype='object')

# %% [markdown]
# Join function gives error if not given all the arguments mentioned in below cells.

# %%
# Join requires all the arguments as mentioned in the cell 
df1.join(df2, how='outer', on='FellowshipID',lsuffix='_Left',rsuffix='_Right')
# Out:
#      FellowshipID  FellowshipID_Left FirstName_Left     Skills  \
# 0.0        1001.0             1001.0          Frodo     Hiding
# 1.0        1002.0             1002.0        Samwise  Gardening
# 2.0        1003.0             1003.0        Gandalf     Spells
# 3.0        1004.0             1004.0         Pippin  Fireworks
# NaN           0.0                NaN            NaN        NaN
# NaN           1.0                NaN            NaN        NaN
# NaN           2.0                NaN            NaN        NaN
# NaN           3.0                NaN            NaN        NaN
# NaN           4.0                NaN            NaN        NaN
#
#      FellowshipID_Right FirstName_Right     Age
# 0.0                 NaN             NaN     NaN
# 1.0                 NaN             NaN     NaN
# 2.0                 NaN             NaN     NaN
# 3.0                 NaN             NaN     NaN
# NaN              1001.0           Frodo    50.0
# NaN              1002.0         Samwise    39.0
# NaN              1006.0         Legolas  2931.0
# NaN              1007.0          Elrond  6520.0
# NaN              1008.0        Barromir    51.0

# %%
df1.join(df2, how='inner', on='FellowshipID',lsuffix='_Left',rsuffix='_Right')
# Out:
# Empty DataFrame
# Columns: [FellowshipID, FellowshipID_Left, FirstName_Left, Skills, FellowshipID_Right, FirstName_Right, Age]
# Index: []

# %% [markdown]
# When we take inner it doesn't give any result as Join function when we work with indexes therefore we make indexes to get more better results.

# %%
df3=df1.set_index('FellowshipID').join(df2.set_index('FellowshipID'),lsuffix='_Left',rsuffix='_Right')
df3
# Out:
#              FirstName_Left     Skills FirstName_Right   Age
# FellowshipID
# 1001.0                Frodo     Hiding           Frodo  50.0
# 1002.0              Samwise  Gardening         Samwise  39.0
# 1003.0              Gandalf     Spells             NaN   NaN
# 1004.0               Pippin  Fireworks             NaN   NaN

# %% [markdown]
# Here we can see that we set that a cloumn as our index which makes better result and Join Function has left join as its default joining function.

# %%
df3=df1.set_index('FellowshipID').join(df2.set_index('FellowshipID'),how='inner',lsuffix='_Left',rsuffix='_Right')
df3
# Out:
#              FirstName_Left     Skills FirstName_Right  Age
# FellowshipID
# 1001.0                Frodo     Hiding           Frodo   50
# 1002.0              Samwise  Gardening         Samwise   39

# %% [markdown]
# With indexes we can get inner join of the dataframes.

# %%
df3=df1.set_index('FellowshipID').join(df2.set_index('FellowshipID'),how='outer',lsuffix='_Left',rsuffix='_Right')
df3
# Out:
#              FirstName_Left     Skills FirstName_Right     Age
# FellowshipID
# 1001.0                Frodo     Hiding           Frodo    50.0
# 1002.0              Samwise  Gardening         Samwise    39.0
# 1003.0              Gandalf     Spells             NaN     NaN
# 1004.0               Pippin  Fireworks             NaN     NaN
# 1006.0                  NaN        NaN         Legolas  2931.0
# 1007.0                  NaN        NaN          Elrond  6520.0
# 1008.0                  NaN        NaN        Barromir    51.0

# %% [markdown]
# ## 3.Concat Function
#
# With Concat function we join the dataframes on rows or coulmns based on axis.

# %%
pd.concat([df1,df2]) # the default axis is 0
# Out:
#    FellowshipID FirstName     Skills     Age
# 0        1001.0     Frodo     Hiding     NaN
# 1        1002.0   Samwise  Gardening     NaN
# 2        1003.0   Gandalf     Spells     NaN
# 3        1004.0    Pippin  Fireworks     NaN
# 0        1001.0     Frodo        NaN    50.0
# 1        1002.0   Samwise        NaN    39.0
# 2        1006.0   Legolas        NaN  2931.0
# 3        1007.0    Elrond        NaN  6520.0
# 4        1008.0  Barromir        NaN    51.0

# %%
pd.concat([df1,df2], join='outer')
# Out:
#    FellowshipID FirstName     Skills     Age
# 0        1001.0     Frodo     Hiding     NaN
# 1        1002.0   Samwise  Gardening     NaN
# 2        1003.0   Gandalf     Spells     NaN
# 3        1004.0    Pippin  Fireworks     NaN
# 0        1001.0     Frodo        NaN    50.0
# 1        1002.0   Samwise        NaN    39.0
# 2        1006.0   Legolas        NaN  2931.0
# 3        1007.0    Elrond        NaN  6520.0
# 4        1008.0  Barromir        NaN    51.0

# %%
pd.concat([df1,df2], join='inner')
# Out:
#    FellowshipID FirstName
# 0        1001.0     Frodo
# 1        1002.0   Samwise
# 2        1003.0   Gandalf
# 3        1004.0    Pippin
# 0        1001.0     Frodo
# 1        1002.0   Samwise
# 2        1006.0   Legolas
# 3        1007.0    Elrond
# 4        1008.0  Barromir

# %% [markdown]
# When we take inner it takes only the columns present in both the dataframes .

# %%
pd.concat([df1,df2], join='inner', axis=1)
# Out:
#    FellowshipID FirstName     Skills  FellowshipID FirstName   Age
# 0        1001.0     Frodo     Hiding          1001     Frodo    50
# 1        1002.0   Samwise  Gardening          1002   Samwise    39
# 2        1003.0   Gandalf     Spells          1006   Legolas  2931
# 3        1004.0    Pippin  Fireworks          1007    Elrond  6520

# %% [markdown]
# Here it is taking inner join based on the index and axis=1 makes dataframes stand side by side .

# %%
pd.concat([df1,df2], join='outer', axis=1)
# Out:
#    FellowshipID FirstName     Skills  FellowshipID FirstName   Age
# 0        1001.0     Frodo     Hiding          1001     Frodo    50
# 1        1002.0   Samwise  Gardening          1002   Samwise    39
# 2        1003.0   Gandalf     Spells          1006   Legolas  2931
# 3        1004.0    Pippin  Fireworks          1007    Elrond  6520
# 4           NaN       NaN        NaN          1008  Barromir    51

# %% [markdown]
# Now when we take outer join it will give all the rows from first as well as second dataframe.
